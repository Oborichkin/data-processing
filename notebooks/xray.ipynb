# %%
import sys
sys.path.append('../')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from src.base.line import Line
from src.data_processing.io.image import Image
from src.data_processing.proc.filters import bsf_line, bsf_pic

# %%
img = Image.from_xcr("../data/h400x300.xcr", w=300, h=400)
img.plot()

# %%
test_line = Line(img.img[42])
plt.figure(figsize=(20, 5))
test_line.plot()

# %%
from src.data_processing.analysis import dft, get_frequency_spectrum

# %%
plt.figure(figsize=(20, 5))
get_frequency_spectrum(dft(test_line)).plot()

# %%
filtered_line = bsf_line(test_line, low=100, high=125)
plt.figure(figsize=(20, 5))
filtered_line.plot()

# %%
plt.figure(figsize=(20, 5))
get_frequency_spectrum(dft(filtered_line)).plot()

# %%
filtered_pic = bsf_pic(img, low=100, high=150)
filtered_pic.plot()
