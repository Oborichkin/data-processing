# %%
import sys
sys.path.append('../')

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from src.data_processing.model.cardio import Cardiogram
from src.data_processing.proc import convolution, deconvolution

# %%
dots = 1000
freq = 10
dt = 0.005
interval = 200
relaxation = 15

# %%
card = Cardiogram(dots, freq, dt, interval, relaxation)

# %%
plt.figure(figsize=(25,5))
plt.plot(card.y)

# %%
plt.figure(figsize=(25,5))
plt.plot(card.base.y)

# %%
plt.figure(figsize=(25,5))
plt.plot(card.delta.y)

# %%
deconv = deconvolution(card, card.base)
# Out:
# 1000
# 1000

# %%
plt.figure(figsize=(25,5))
plt.plot(deconv.y)
